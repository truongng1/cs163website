# %% [markdown]
# ## 911 Calls Dataset Preprocessing

# %%
import pandas as pd

# %%
df_2013 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2013.csv', sep  = ',')
df_2014 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2014.csv', sep  = ',')
df_2015 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2015.csv', sep  = ',')
df_2016 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2016.csv', sep  = ',')
df_2017 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2017.csv', sep  = ',')
df_2018 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2018.csv', sep  = ',')
df_2019 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2019.csv', sep  = ',')
df_2020 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2020.csv', sep  = ',')
df_2021 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2021.csv', sep  = ',')
df_2022 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2022.csv', sep  = ',')
df_2023 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2023.csv', sep  = ',')
df_2024 = pd.read_csv('https://storage.googleapis.com/cs163-seniorproject.appspot.com/dataset/911_calls/raw_dataset/policecalls2024.csv', sep  = ',')

# %%
df_2013.head()
# Out:
#                CDTS      EID             START_DATE CALL_NUMBER  PRIORITY  \
# 0  20130101000052PS  4684476  5/13/2021 12:00:00 AM  P123660873         4
# 1  20130101032822PS  4684484  5/13/2021 12:00:00 AM  P130010002         4
# 2  20130101002612PS  4684485  5/13/2021 12:00:00 AM  P130010003         2
# 3  20130101000624PS  4684486  5/13/2021 12:00:00 AM  P130010004         2
# 4  20130101000303PS  4684487  5/13/2021 12:00:00 AM  P130010005         4
#
#             REPORT_DATE          OFFENSE_DATE OFFENSE_TIME CALLTYPE_CODE  \
# 0  1/1/2013 12:00:00 AM  1/1/2013 12:00:00 AM     00:00:06         415FC
# 1  1/1/2013 12:00:00 AM  1/1/2013 12:00:00 AM     00:01:05          1062
# 2  1/1/2013 12:00:00 AM  1/1/2013 12:00:00 AM     00:02:01          1057
# 3  1/1/2013 12:00:00 AM  1/1/2013 12:00:00 AM     00:02:43          1057
# 4  1/1/2013 12:00:00 AM  1/1/2013 12:00:00 AM     00:02:49         415FC
#
#                    CALL_TYPE FINAL_DISPO_CODE                     FINAL_DISPO  \
# 0  DISTURBANCE, FIRECRACKERS               NR                     No Response
# 1           MEET THE CITIZEN                G  Gone on Arrival/unable to loca
# 2        FIREARMS DISCHARGED               NR                     No Response
# 3        FIREARMS DISCHARGED               NR                     No Response
# 4  DISTURBANCE, FIRECRACKERS              CAN                        Canceled
#
#                          ADDRESS      CITY STATE
# 0            UTOPIA PL & PEAK DR  San Jose    CA
# 1         QUIMBY RD & S WHITE RD  San Jose    CA
# 2         [3500]-[3600] PAYNE AV  San Jose    CA
# 3          [800]-[900] SAKURA DR  San Jose    CA
# 4  VINEYARD DR & SANTA TERESA BL  San Jose    CA

# %%
frames = [df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023, df_2024]

# %%
result = pd.concat(frames)

# %%
result
# Out:
#                     CDTS       EID              START_DATE CALL_NUMBER  \
# 0       20130101000052PS   4684476   5/13/2021 12:00:00 AM  P123660873
# 1       20130101032822PS   4684484   5/13/2021 12:00:00 AM  P130010002
# 2       20130101002612PS   4684485   5/13/2021 12:00:00 AM  P130010003
# 3       20130101000624PS   4684486   5/13/2021 12:00:00 AM  P130010004
# 4       20130101000303PS   4684487   5/13/2021 12:00:00 AM  P130010005
# ...                  ...       ...                     ...         ...
# 276064  20250101023534PS  10305810  12/31/2024 12:00:00 AM  P243660883
# 276065  20241231235336PS  10305811  12/31/2024 12:00:00 AM  P243660884
# 276066  20250101010534PS  10305812  12/31/2024 12:00:00 AM  P243660885
# 276067  20250101002143PS  10305813  12/31/2024 12:00:00 AM  P243660886
# 276068  20250101001359PS  10305814  12/31/2024 12:00:00 AM  P243660887
#
#         PRIORITY             REPORT_DATE            OFFENSE_DATE OFFENSE_TIME  \
# 0              4    1/1/2013 12:00:00 AM    1/1/2013 12:00:00 AM     00:00:06
# 1              4    1/1/2013 12:00:00 AM    1/1/2013 12:00:00 AM     00:01:05
# 2              2    1/1/2013 12:00:00 AM    1/1/2013 12:00:00 AM     00:02:01
# 3              2    1/1/2013 12:00:00 AM    1/1/2013 12:00:00 AM     00:02:43
# 4              4    1/1/2013 12:00:00 AM    1/1/2013 12:00:00 AM     00:02:49
# ...          ...                     ...                     ...          ...
# 276064         3  12/31/2024 12:00:00 AM  12/31/2024 12:00:00 AM     23:48:36
# 276065         2  12/31/2024 12:00:00 AM  12/31/2024 12:00:00 AM     23:48:40
# 276066         4  12/31/2024 12:00:00 AM  12/31/2024 12:00:00 AM     23:50:27
# 276067         3  12/31/2024 12:00:00 AM  12/31/2024 12:00:00 AM     23:57:51
# 276068         2  12/31/2024 12:00:00 AM  12/31/2024 12:00:00 AM     23:59:20
#
#        CALLTYPE_CODE                  CALL_TYPE FINAL_DISPO_CODE  \
# 0              415FC  DISTURBANCE, FIRECRACKERS               NR
# 1               1062           MEET THE CITIZEN                G
# 2               1057        FIREARMS DISCHARGED               NR
# 3               1057        FIREARMS DISCHARGED               NR
# 4              415FC  DISTURBANCE, FIRECRACKERS              CAN
# ...              ...                        ...              ...
# 276064         1033A             ALARM, AUDIBLE                U
# 276065           415                DISTURBANCE              CAN
# 276066          415M         DISTURBANCE, MUSIC              CAN
# 276067          415F        DISTURBANCE, FAMILY                N
# 276068           415                DISTURBANCE                N
#
#                                      FINAL_DISPO  \
# 0                                    No Response
# 1                 Gone on Arrival/unable to loca
# 2                                    No Response
# 3                                    No Response
# 4                                       Canceled
# ...                                          ...
# 276064                           Unfounded event
# 276065                                  Canceled
# 276066                                  Canceled
# 276067  No report required; dispatch record only
# 276068  No report required; dispatch record only
#
#                               ADDRESS      CITY STATE
# 0                 UTOPIA PL & PEAK DR  San Jose    CA
# 1              QUIMBY RD & S WHITE RD  San Jose    CA
# 2              [3500]-[3600] PAYNE AV  San Jose    CA
# 3               [800]-[900] SAKURA DR  San Jose    CA
# 4       VINEYARD DR & SANTA TERESA BL  San Jose    CA
# ...                               ...       ...   ...
# 276064     [4100]-[4200] MONTEREY RD   San Jose    CA
# 276065        [1700]-[1800] TULLY RD   San Jose    CA
# 276066  [1100]-[1200] ROYAL CREST DR   San Jose    CA
# 276067        [2700]-[2800] STORY RD   San Jose    CA
# 276068          [400]-[500] S 1ST ST   San Jose    CA
#
# [3670178 rows x 15 columns]

# %%
result = result.drop(['CDTS', 'EID', 'START_DATE', 'CALL_NUMBER','REPORT_DATE', 'FINAL_DISPO_CODE'], axis = 1)

# %%
result
# Out:
#         PRIORITY            OFFENSE_DATE OFFENSE_TIME CALLTYPE_CODE  \
# 0              4    1/1/2013 12:00:00 AM     00:00:06         415FC
# 1              4    1/1/2013 12:00:00 AM     00:01:05          1062
# 2              2    1/1/2013 12:00:00 AM     00:02:01          1057
# 3              2    1/1/2013 12:00:00 AM     00:02:43          1057
# 4              4    1/1/2013 12:00:00 AM     00:02:49         415FC
# ...          ...                     ...          ...           ...
# 276064         3  12/31/2024 12:00:00 AM     23:48:36         1033A
# 276065         2  12/31/2024 12:00:00 AM     23:48:40           415
# 276066         4  12/31/2024 12:00:00 AM     23:50:27          415M
# 276067         3  12/31/2024 12:00:00 AM     23:57:51          415F
# 276068         2  12/31/2024 12:00:00 AM     23:59:20           415
#
#                         CALL_TYPE                               FINAL_DISPO  \
# 0       DISTURBANCE, FIRECRACKERS                               No Response
# 1                MEET THE CITIZEN            Gone on Arrival/unable to loca
# 2             FIREARMS DISCHARGED                               No Response
# 3             FIREARMS DISCHARGED                               No Response
# 4       DISTURBANCE, FIRECRACKERS                                  Canceled
# ...                           ...                                       ...
# 276064             ALARM, AUDIBLE                           Unfounded event
# 276065                DISTURBANCE                                  Canceled
# 276066         DISTURBANCE, MUSIC                                  Canceled
# 276067        DISTURBANCE, FAMILY  No report required; dispatch record only
# 276068                DISTURBANCE  No report required; dispatch record only
#
#                               ADDRESS      CITY STATE
# 0                 UTOPIA PL & PEAK DR  San Jose    CA
# 1              QUIMBY RD & S WHITE RD  San Jose    CA
# 2              [3500]-[3600] PAYNE AV  San Jose    CA
# 3               [800]-[900] SAKURA DR  San Jose    CA
# 4       VINEYARD DR & SANTA TERESA BL  San Jose    CA
# ...                               ...       ...   ...
# 276064     [4100]-[4200] MONTEREY RD   San Jose    CA
# 276065        [1700]-[1800] TULLY RD   San Jose    CA
# 276066  [1100]-[1200] ROYAL CREST DR   San Jose    CA
# 276067        [2700]-[2800] STORY RD   San Jose    CA
# 276068          [400]-[500] S 1ST ST   San Jose    CA
#
# [3670178 rows x 9 columns]

# %%
result['CALL_TYPE'].unique()
# Out:
# array(['DISTURBANCE, FIRECRACKERS', 'MEET THE CITIZEN',
#        'FIREARMS DISCHARGED', 'DISTURBANCE, FAMILY', 'DRUNK IN PUBLIC',
#        'ALARM, AUDIBLE', 'MENTALLY DISTURBED PERSON', 'MISSING FEMALE',
#        'ALARM, SILENT', 'MISDEMEANOR HIT AND RUN', 'RECKLESS DRIVING',
#        'DISTURBANCE, MUSIC', 'ALARM', 'UNK TYPE 911 CALL FROM CELL',
#        'MISDEMEANOR DUI', 'SUSPICIOUS CIRCUMSTANCES',
#        'DISTURBANCE, FIGHT', 'STOLEN VEHICLE',
#        'VEHICLE ACCIDENT, PROPERTY DAM', 'DISTURBANCE',
#        'SUSPICIOUS VEHICLE', 'SUSPICIOUS PERSON',
#        'FEMALE CALLING FOR HELP', 'PROWLER', 'DISTURBANCE, UNKNOWN',
#        'BATTERY', 'PARKING VIOLATION', 'VEHICLE STOP', 'PEDESTRIAN STOP',
#        'TRAFFIC HAZARD', 'VEHICLE ACCIDENT, AMB DISPATCH',
#        'DEFRAUDING AN INKEEPER', 'WELFARE CHECK', 'PERSON DOWN',
#        'TRESPASSING', 'THEFT', 'MALICIOUS MISCHIEF',
#        'SHOOTING INTO OCCP VEH OR DWEL', 'THROWING SUBSTANCES AT VEHICLE',
#        'RECOVERED STOLEN VEHICLE', 'PERSON STABBED',
#        'ASSAULT WITH DEADLY WEAPON', 'FALSE IMPRISONMENT',
#        'UNK TYPE 911 CALL', 'WELFARE CHECK (COMBINED EVENT)',
#        'BURGLARY (460)', 'DISTURBANCE, WEAPON', 'BRANDISHING A WEAPON',
#        'DISTURBANCE, FAMILY (COMBINED ', 'POSSESSION OF MARIJUANA',
#        'VEHICLE BURGLARY', 'UNK TYPE 911 CALL FROM RESD',
#        'BURGLARY  REPORT  (460)', 'ARSON (447A)', 'DISTURBANCE, NEIGHBOR',
#        'PUBLIC SAFETY ASSISTANCE', 'ROBBERY', 'ARMED ROBBERY',
#        'ABANDONED VEHICLE', 'UNK TYPE 911 CALL FROM BUSN',
#        'SUSPICIOUS PERSON W/ WEAPON', 'FIRE DEPARTMENT REQUEST FOR PD',
#        'TRAFFIC CONTROL', 'UNK TYPE 911 CALL FROM VOIP TE',
#        'FOUND PROPERTY', 'RECEIVE/POSSESS STOLEN PROP', 'NARCOTICS',
#        'MISSING JUVENILE', 'POSSESSION OF NARCOTICS, GANG ',
#        'MISSING PERSON, MENTAL HANDICA', 'INJURED ANIMAL',
#        'TAMPERING WITH A VEHICLE', 'BATTERY, SERIOUS INJURY', 'VAGRANT',
#        'CRIMINAL THREATS', 'DRIVING W/SUSPENDED LICENSE',
#        'BATTERY (COMBINED EVENT)', 'POSSESSION OF NARCOTICS',
#        'FELONY WANT', 'UNK TYPE 911 CALL FROM PAYPHON', 'CORONERS CASE',
#        'VEHICLE ACCIDENT, MINOR INJURI', 'FORGERY', 'OPEN DOOR',
#        'FELONY DUI', 'FELONY HIT AND RUN', 'EXPLOSION',
#        'HANDICAPPED PARKING VIOLATION', 'POSSESSION OF CONTROLLED SUBST',
#        'VEHICLE STOP ON FEMALE', 'UNLICENSED DRIVER',
#        'DISTURBANCE, FIGHT (COMBINED E', 'SICK PERSON',
#        'MOLEST/ANNOY UNDER 18YRS', 'SUSPICIOUS FEMALE',
#        'MENTALLY DISTURBED FEMALE', 'BAD CHECKS',
#        'PERSON CALLING FOR HELP', 'DISTURBANCE, JUVENILE',
#        'PETTY THEFT (BROADCAST ONLY)', 'VIOLATION OF PROTECTIVE ORDER',
#        'EMBEZZLEMENT', 'PEDESTRIAN STOP ON FEMALE', 'VICIOUS ANIMAL',
#        'MISDEMEANOR WANT', 'FOUND, MISSING PERSON', 'ALARM, SVRN',
#        'VEHICLE ACCIDENT, UNKNOWN INJU', 'MALICIOUS MISCHIEF, GANG RELAT',
#        'STRONG ARM ROBBERY', 'NARCOTICS, GANG RELATED',
#        'SOLICITING FOR PROSTITUTION', 'PETTY THEFT',
#        'ILLEGAL WEAPONS, GANG RELATED', 'THEFT OF RECYCLABLES',
#        'KIDNAPPING', 'RESISTING ARREST', 'SUSPICIOUS PACKAGE',
#        'ASSAULT AND BATTERY', 'COMMUNIT POLICING BIKE',
#        'DISTURBANCE (COMBINED EVENT)', 'INDECENT EXPOSURE',
#        'CIVIL MATTER', 'MISSING PERSON', 'SUSPICIOUS CIRCUMSTANCES (COMB',
#        'USE OF CONTROLLED SUBSTANCE', 'CARRYING A CONCEALED WEAPON',
#        'CARJACKING (COMBINED EVENT)', 'ASSAULT WITH DEADLY WEAPON (CO',
#        'SOLICITING FOR LEWD CONDUCT', 'SPEED CONTEST',
#        'OBSCENE OR HARASSING PH CALLS', 'ARMED ROBBERY (COMBINED EVENT)',
#        'PAROLE VIOLATION', 'CRUELTY TO ANIMALS',
#        'DISTURBANCE, WEAPON (COMBINED ', 'DISTURBANCE, UNKNOWN (COMBINED',
#        'DISTURBANCE, GANG', 'STOLEN VEHICLE, GANG RELATED',
#        'INTOXICATED PERSON', 'SELL OR FURN ALCOHOL TO MINOR',
#        'PERSON SHOT', 'EXPIRED REGISTRATION',
#        'PETTY THEFT PRIOR CONVICTION', 'ANIMAL COMPLAINT',
#        'VEHICLE ACCIDENT, MAJOR INJURI', 'MURDER',
#        'COMMUNITY POLICING OFFICE', 'DISTURBANCE, JUVENILE GANG',
#        'FIRE (SPECIFY TYPE)', 'CHILD ABUSE', 'MISSING FEMALE JUVENILE',
#        'ILLEGAL WEAPONS', 'ASSAULT WITH DEADLY WEAPON, GA',
#        'GARBAGE COMPLAINT', 'COMMUNITY POLICING SCHOOL', 'TRUANT (TABS)',
#        'ELDER/DEPENDENT ADULT ABUSE', 'COMMUNITY POLICING MEETING',
#        'GRAND THEFT', 'SPEEDING', 'W&I-UNDER JURIS OF JUV COURT',
#        'INJURED PERSON', '1091AB          - VICIOUS ANIM',
#        'BRANDISHING A WEAPON, GANG', 'PURSE SNATCH ROBBERY', 'ASSAULT',
#        'BATTERY ON AN OFFICER', 'HI-TECH CRIMES', 'OPEN WINDOW',
#        'DEAD ANIMAL', 'STALKING', 'DISTURBANCE, MOTORCYCLE',
#        'MINOR IN POSSESSION OF ALCOHOL', 'BOMB THREAT', 'TAKE A REPORT',
#        'REGISTRATION OF SEX OFFENDER', 'BREACH OF AOA',
#        'OBSTRUCT MEDICAL CLINIC-PERSON', 'STRAY HORSE',
#        'ASSAULT ON AN OFFICER', 'COMMUNITY POLICING -CITZ ASSIS',
#        'SALE OF TOBACCO TO MINOR', 'SUSPICIOUS PERSON (GANG)',
#        'BATTERY ON A PEACE OFFICER', 'CHILD BEATING',
#        'TRACE DETECTION ALARM/AIRPORT', 'PEDESTRIAN STOP, SEND FILL',
#        'DRIVING W/SUS LIC-VEH IMPOUNDE', 'PEDESTRIAN STOP-CURFEW VIOL',
#        'RESISTING ARREST, GANG RELATED', 'DISTURBANCE, FAMILY GANG',
#        'ROBBERY, GANG RELATED', 'BATTERY, GANG RELATED', 'HATE CRIMES',
#        'VEHICLE STOP, SEND FILL', 'STRONG ARM ROBBERY (COMBINED E',
#        'ARMED ROBBERY, GANG RELATED', 'W&I UNCONTROLLABLE JUVENILE',
#        'EXTORTION', 'NOISY ANIMAL', 'BAR CHECK',
#        'DOMESTIC VIOLENCE  (COMBINED E', 'THEFT, GANG RELATED',
#        'DISTURBANCE, FIGHT GANG', 'INJURE, OBSTRUCT A BUSINESS',
#        'JUVENILE VIOLATING COURT ORDER', 'DROWNING',
#        'REFUSAL TO LEAVE PROPERTY', 'EXTORTION, GANG RELATED',
#        'SUSPICIOUS PERSON ON RUNWAY - ', '911 CALL FROM AIRBORNE AIRCRAF',
#        'BOMB REMOVAL, STANDBY', 'OBSTRUCT STREETS OR SIDEWALK', nan,
#        'ALARM, PREPROCESSING', 'JOYRIDING',
#        'VEHICLE STOP ON X, SEND FILL', 'ALTERED VIN NUMBER',
#        'X-RAY MACHINE ALARM/AIRPORT', 'CONTROLLED SUBSTANCE AT RESIDE',
#        'OFFICER NEEDS ASSIST, EMERG', 'CURFEW TRANS/CURF CTR TO RESD',
#        'CARSTOP ON FEMALE (BACK IN)', 'VEHICLE ACCIDENT, PROPERTY DAMAGE',
#        'DOMESTIC VIOLENCE  (COMBINED EVENT)',
#        'SHOOTING INTO OCCP VEH OR DWELLING',
#        'POSSESSION OF CONTROLLED SUBSTANCE, GANG RELATED',
#        'VEHICLE ACCIDENT, MINOR INJURIES',
#        'VEHICLE ACCIDENT, AMB DISPATCHED',
#        '1091AB          - VICIOUS ANIMAL (COMBINED EVENT)',
#        'POSSESSION OF CONTROLLED SUBSTANCE',
#        'VEHICLE ACCIDENT, UNKNOWN INJURIES',
#        'MALICIOUS MISCHIEF, GANG RELATED',
#        'DISTURBANCE, FAMILY (COMBINED EVENT)',
#        'MISSING PERSON, MENTAL HANDICAP',
#        'SUSPICIOUS CIRCUMSTANCES (COMBINED EVENT)',
#        'VEHICLE ACCIDENT, MAJOR INJURIES',
#        'DISTURBANCE, FIGHT (COMBINED EVENT)',
#        'ASSAULT WITH DEADLY WEAPON, GANG',
#        'ASSAULT WITH DEADLY WEAPON (COMBINED EVENT)',
#        'POSSESSION OF NARCOTICS, GANG RELATED',
#        'DISTURBANCE, WEAPON (COMBINED EVENT)',
#        'STRONG ARM ROBBERY (COMBINED EVENT)',
#        'DISTURBANCE, UNKNOWN (COMBINED EVENT)',
#        'COMMUNITY POLICING -CITZ ASSIST',
#        'SUSPICIOUS PERSON ON RUNWAY - SJIA',
#        'DRIVING W/SUS LIC-VEH IMPOUNDED', 'FIRE *** 911 DESK ***'],
#       dtype=object)

# %%
call_type_mapping = {
    'Violent Crimes': ['MURDER', 'ASSAULT', 'ASSAULT WITH DEADLY WEAPON', 'ASSAULT WITH DEADLY WEAPON, GANG', 'ASSAULT ON AN OFFICER', 'BATTERY', 'BATTERY ON AN OFFICER', 'BATTERY ON A PEACE OFFICER', 'BATTERY, SERIOUS INJURY', 'BATTERY, GANG RELATED', 'PERSON STABBED', 'PERSON SHOT', 'SHOOTING INTO OCCP VEH OR DWELLING', 'CRIMINAL THREATS', 'KIDNAPPING', 'FALSE IMPRISONMENT', 'CHILD ABUSE', 'CHILD BEATING', 'ELDER/DEPENDENT ADULT ABUSE', 'DOMESTIC VIOLENCE', 'STALKING', 'HATE CRIMES'],
    'Property Crimes': ['THEFT', 'PETTY THEFT', 'GRAND THEFT', 'PURSE SNATCH ROBBERY', 'THEFT OF RECYCLABLES', 'THEFT, GANG RELATED', 'BURGLARY (460)', 'BURGLARY REPORT (460)', 'VEHICLE BURGLARY', 'ROBBERY', 'ARMED ROBBERY', 'ARMED ROBBERY, GANG RELATED', 'STRONG ARM ROBBERY', 'CARJACKING', 'STOLEN VEHICLE', 'STOLEN VEHICLE, GANG RELATED', 'RECOVERED STOLEN VEHICLE', 'RECEIVE/POSSESS STOLEN PROP', 'MALICIOUS MISCHIEF', 'MALICIOUS MISCHIEF, GANG RELATED', 'ARSON (447A)', 'TAMPERING WITH A VEHICLE', 'FORGERY', 'EMBEZZLEMENT', 'DEFRAUDING AN INNKEEPER', 'EXTORTION', 'EXTORTION, GANG RELATED'],
    'Weapons Related': ['FIREARMS DISCHARGED', 'BRANDISHING A WEAPON', 'BRANDISHING A WEAPON, GANG', 'CARRYING A CONCEALED WEAPON', 'ILLEGAL WEAPONS', 'ILLEGAL WEAPONS, GANG RELATED', 'DISTURBANCE, WEAPON', 'SUSPICIOUS PERSON W/ WEAPON'],
    'Public Disturbances': ['DISTURBANCE', 'DISTURBANCE, FAMILY', 'DISTURBANCE, FIGHT', 'DISTURBANCE, MUSIC', 'DISTURBANCE, NEIGHBOR', 'DISTURBANCE, UNKNOWN', 'DISTURBANCE, JUVENILE', 'DISTURBANCE, GANG', 'DISTURBANCE, JUVENILE GANG', 'DISTURBANCE, MOTORCYCLE', 'DISTURBANCE, FIRECRACKERS', 'THROWING SUBSTANCES AT VEHICLE', 'INDECENT EXPOSURE', 'OBSCENE OR HARASSING PH CALLS', 'NOISY ANIMAL'],
    'Substance Offenses': ['DRUNK IN PUBLIC', 'INTOXICATED PERSON', 'MISDEMEANOR DUI', 'FELONY DUI', 'POSSESSION OF MARIJUANA', 'POSSESSION OF NARCOTICS', 'POSSESSION OF NARCOTICS, GANG RELATED', 'POSSESSION OF CONTROLLED SUBSTANCE', 'POSSESSION OF CONTROLLED SUBSTANCE, GANG RELATED', 'USE OF CONTROLLED SUBSTANCE', 'NARCOTICS', 'NARCOTICS, GANG RELATED', 'SELL OR FURN ALCOHOL TO MINOR', 'MINOR IN POSSESSION OF ALCOHOL'],
    'Traffic and Vehicle Incidents': ['RECKLESS DRIVING', 'SPEEDING', 'SPEED CONTEST', 'MISDEMEANOR HIT AND RUN', 'FELONY HIT AND RUN', 'DRIVING W/SUSPENDED LICENSE', 'DRIVING W/SUS LIC-VEH IMPOUNDED', 'UNLICENSED DRIVER', 'VEHICLE ACCIDENT, PROPERTY DAMAGE', 'VEHICLE ACCIDENT, MINOR INJURIES', 'VEHICLE ACCIDENT, MAJOR INJURIES', 'VEHICLE ACCIDENT, UNKNOWN INJURIES', 'VEHICLE ACCIDENT, AMB DISPATCHED', 'TRAFFIC HAZARD', 'TRAFFIC CONTROL', 'VEHICLE STOP', 'PEDESTRIAN STOP', 'ABANDONED VEHICLE', 'SUSPICIOUS VEHICLE', 'PARKING VIOLATION', 'HANDICAPPED PARKING VIOLATION', 'EXPIRED REGISTRATION', 'ALTERED VIN NUMBER', 'JOYRIDING'],
    'Suspicious Activity': ['SUSPICIOUS PERSON', 'SUSPICIOUS FEMALE', 'SUSPICIOUS PERSON (GANG)', 'SUSPICIOUS CIRCUMSTANCES', 'SUSPICIOUS PACKAGE', 'PROWLER', 'OPEN DOOR', 'OPEN WINDOW'],
    'Public Safety': ['WELFARE CHECK', 'PERSON DOWN', 'SICK PERSON', 'INJURED PERSON', 'INJURED ANIMAL', 'MENTALLY DISTURBED PERSON', 'MENTALLY DISTURBED FEMALE', 'MISSING PERSON', 'MISSING FEMALE', 'MISSING JUVENILE', 'MISSING FEMALE JUVENILE', 'MISSING PERSON, MENTAL HANDICAP', 'FOUND, MISSING PERSON', 'FEMALE CALLING FOR HELP', 'PERSON CALLING FOR HELP', 'FIRE (SPECIFY TYPE)', 'EXPLOSION', 'BOMB THREAT', 'CORONERS CASE', 'PUBLIC SAFETY ASSISTANCE', 'FIRE DEPARTMENT REQUEST FOR PD'],
    'Juvenile and Minor Incidents': ['TRUANT (TABS)', 'W&I-UNDER JURIS OF JUV COURT', 'W&I UNCONTROLLABLE JUVENILE', 'JUVENILE VIOLATING COURT ORDER', 'MOLEST/ANNOY UNDER 18YRS'],
    'Miscellaneous Crimes and Violations': ['TRESPASSING', 'RESISTING ARREST', 'RESISTING ARREST, GANG RELATED', 'VIOLATION OF PROTECTIVE ORDER', 'PAROLE VIOLATION', 'SOLICITING FOR PROSTITUTION', 'SOLICITING FOR LEWD CONDUCT', 'BAD CHECKS', 'VAGRANT', 'CRUELTY TO ANIMALS', 'VICIOUS ANIMAL', 'ANIMAL COMPLAINT', 'DEAD ANIMAL', 'STRAY HORSE', 'GARBAGE COMPLAINT', 'CIVIL MATTER', 'OBSTRUCT STREETS OR SIDEWALK', 'REFUSAL TO LEAVE PROPERTY'],
    'Alarms and 911 Calls': ['ALARM', 'ALARM, AUDIBLE', 'ALARM, SILENT', 'ALARM, SVRN', 'UNK TYPE 911 CALL', 'UNK TYPE 911 CALL FROM CELL', 'UNK TYPE 911 CALL FROM RESD', 'UNK TYPE 911 CALL FROM BUSN', 'UNK TYPE 911 CALL FROM PAYPHON', 'UNK TYPE 911 CALL FROM VOIP TE', '911 CALL FROM AIRBORNE AIRCRAFT'],
    'Community Policing': ['COMMUNITY POLICING OFFICE', 'COMMUNITY POLICING SCHOOL', 'COMMUNITY POLICING MEETING', 'COMMUNITY POLICING -CITZ ASSIST', 'MEET THE CITIZEN', 'TAKE A REPORT', 'FOUND PROPERTY', 'REGISTRATION OF SEX OFFENDER']
}

# %%
def categorize_call_type(call_type):
    for category, types in call_type_mapping.items():
        if call_type in types:
            return category
    return 'OTHER'

result['CALL_TYPE'] = result['CALL_TYPE'].apply(lambda x: categorize_call_type(str(x)))

# %%
result['CALL_TYPE'].unique()
# Out:
# array(['Public Disturbances', 'Community Policing', 'Weapons Related',
#        'Substance Offenses', 'Alarms and 911 Calls', 'Public Safety',
#        'Traffic and Vehicle Incidents', 'Suspicious Activity',
#        'Property Crimes', 'OTHER', 'Violent Crimes',
#        'Miscellaneous Crimes and Violations',
#        'Juvenile and Minor Incidents'], dtype=object)

# %%
result['FINAL_DISPO'].unique()
# Out:
# array(['No Response', 'Gone on Arrival/unable to loca', 'Canceled',
#        'No report required; dispatch r', 'No Disposition', 'Report taken',
#        'Supplemental report taken', 'Courtesy Service/Citizen or ag',
#        'Arrest Made', 'Turned over To (TOT)', 'Unfounded event',
#        'Arrest by Warrant', 'Field Interview (F.I.) Complet',
#        'Traffic Citation Issued, Non-H', 'Prior case, follow-up activity',
#        'Criminal Citation', 'Traffic Citation Issued, Hazar',
#        'Stranded motorist assist',
#        'Traffic Citation Issued, Hazardous Violation',
#        'No report required; dispatch record only',
#        'Gone on Arrival/unable to locate',
#        'Courtesy Service/Citizen or agency assist',
#        'Traffic Citation Issued, Non-Hazardous Violation',
#        'Field Interview (F.I.) Completed',
#        'Prior case, follow-up activity only'], dtype=object)

# %%
decision_mapping = {
    'No Action or Unresolved': [
        'No Response',
        'Gone on Arrival/unable to locate',
        'Gone on Arrival/unable to loca',
        'Canceled',
        'No Disposition',
        'Unfounded event'
    ],
    'Report Related Outcomes': [
        'No report required; dispatch record only',
        'Report taken',
        'Supplemental report taken',
        'Prior case, follow-up activity only'
    ],
    'Citizen or Agency Assistance': [
        'Courtesy Service/Citizen or agency assist',
        'Stranded motorist assist'
    ],
    'Law Enforcement Actions': [
        'Arrest Made',
        'Arrest by Warrant',
        'Turned over To (TOT)',
        'Field Interview (F.I.) Completed',
        'Field Interview (F.I.) Complet',
        'Criminal Citation'
    ],
    'Traffic Citations': [
        'Traffic Citation Issued, Non-Hazardous Violation',
        'Traffic Citation Issued, Non-H',
        'Traffic Citation Issued, Hazar',
        'Traffic Citation Issued, Hazardous Violation'
    ]
}

# %%
def categorize_decision_type(decision_type):
    for category, types in decision_mapping.items():
        if decision_type in types:
            return category
    return 'OTHER'

result['FINAL_DISPO'] = result['FINAL_DISPO'].apply(lambda x: categorize_decision_type(str(x)))

# %%
result['FINAL_DISPO'].unique()
# Out:
# array(['No Action or Unresolved', 'OTHER', 'Report Related Outcomes',
#        'Law Enforcement Actions', 'Traffic Citations',
#        'Citizen or Agency Assistance'], dtype=object)

# %%
result['OFFENSE_DATE'] = pd.to_datetime(result['OFFENSE_DATE'])
# Out:
# /var/folders/rk/pqkf6b3d2pvdw7l0_7hs338c0000gn/T/ipykernel_34478/1964578596.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   result['OFFENSE_DATE'] = pd.to_datetime(result['OFFENSE_DATE'])

# %%
result
# Out:
#         PRIORITY OFFENSE_DATE OFFENSE_TIME CALLTYPE_CODE  \
# 0              4   2013-01-01     00:00:06         415FC
# 1              4   2013-01-01     00:01:05          1062
# 2              2   2013-01-01     00:02:01          1057
# 3              2   2013-01-01     00:02:43          1057
# 4              4   2013-01-01     00:02:49         415FC
# ...          ...          ...          ...           ...
# 276064         3   2024-12-31     23:48:36         1033A
# 276065         2   2024-12-31     23:48:40           415
# 276066         4   2024-12-31     23:50:27          415M
# 276067         3   2024-12-31     23:57:51          415F
# 276068         2   2024-12-31     23:59:20           415
#
#                    CALL_TYPE              FINAL_DISPO  \
# 0        Public Disturbances  No Action or Unresolved
# 1         Community Policing  No Action or Unresolved
# 2            Weapons Related  No Action or Unresolved
# 3            Weapons Related  No Action or Unresolved
# 4        Public Disturbances  No Action or Unresolved
# ...                      ...                      ...
# 276064  Alarms and 911 Calls  No Action or Unresolved
# 276065   Public Disturbances  No Action or Unresolved
# 276066   Public Disturbances  No Action or Unresolved
# 276067   Public Disturbances  Report Related Outcomes
# 276068   Public Disturbances  Report Related Outcomes
#
#                               ADDRESS      CITY STATE
# 0                 UTOPIA PL & PEAK DR  San Jose    CA
# 1              QUIMBY RD & S WHITE RD  San Jose    CA
# 2              [3500]-[3600] PAYNE AV  San Jose    CA
# 3               [800]-[900] SAKURA DR  San Jose    CA
# 4       VINEYARD DR & SANTA TERESA BL  San Jose    CA
# ...                               ...       ...   ...
# 276064     [4100]-[4200] MONTEREY RD   San Jose    CA
# 276065        [1700]-[1800] TULLY RD   San Jose    CA
# 276066  [1100]-[1200] ROYAL CREST DR   San Jose    CA
# 276067        [2700]-[2800] STORY RD   San Jose    CA
# 276068          [400]-[500] S 1ST ST   San Jose    CA
#
# [3670178 rows x 9 columns]
